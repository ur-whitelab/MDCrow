# %%
from mdcrow import MDCrow

# %%
agent = MDCrow(model="gpt-4o-2024-05-13", top_k_tools="all")

# %%
prompt = ("Use protein PDB 1VII."
          "Simulate the folded protein in GROMACS at 300K for 1ns. "
          "Then compare secondary structure (DSSP) at the beginning vs end of the simulation.")

# %%
agent.run(prompt)
# Out:
# PDB file found with this ID: 1VII
#                :-) GROMACS - gmx pdb2gmx, 2025.4-conda_forge (-:
#
# Executable:   /opt/anaconda3/envs/mdc-gromacs/bin.SSE2/gmx
# Data prefix:  /opt/anaconda3/envs/mdc-gromacs
# Working dir:  /Users/samanthacox/MDCrow/ckpt/ckpt_9/gromacs_preparation
# Command line:
#   gmx pdb2gmx -f /Users/samanthacox/MDCrow/ckpt/ckpt_9/pdb/1VII_raw_20260101_145021.pdb -o processed.gro -p topol.top -ff amber99sb-ildn -water tip3p -ignh
#
# Opening force field file /opt/anaconda3/envs/mdc-gromacs/share/gromacs/top/amber99sb-ildn.ff/aminoacids.r2b
# Opening force field file /opt/anaconda3/envs/mdc-gromacs/share/gromacs/top/amber99sb-ildn.ff/dna.r2b
# Opening force field file /opt/anaconda3/envs/mdc-gromacs/share/gromacs/top/amber99sb-ildn.ff/rna.r2b
# All occupancies are one
# Opening force field file /opt/anaconda3/envs/mdc-gromacs/share/gromacs/top/amber99sb-ildn.ff/atomtypes.atp
# ...
